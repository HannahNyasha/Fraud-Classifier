# %%
train=pd.read_csv("training.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-c6c9a59cb8e1> in <module>
# ----> 1 train=pd.read_csv("training.csv")
#
# NameError: name 'pd' is not defined

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import sklearn
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train.head(2)
# Out:
#    TransactionId  BatchId  AccountId SubscriptionId  CustomerId  ProductId  \
# 0          76871    36123       3957            887        4406         10
# 1          73770    15642       4841           3829        4406          6
#
#    ChannelId  Amount  Value  FraudResult
# 0          3  1000.0   1000            0
# 1          2   -20.0     20            0

# %%
train.describe(include='all')
# Out:
#         TransactionId        BatchId     AccountId  SubscriptionId  \
# count    95662.000000   95662.000000  95662.000000         95662.0
# unique            NaN            NaN           NaN          4649.0
# top               NaN            NaN           NaN          3829.0
# freq              NaN            NaN           NaN         22096.0
# mean     70334.481581   70526.339173   3361.571648             NaN
# std      40626.774116   40586.254942   1560.040065             NaN
# min          1.000000       2.000000      1.000000             NaN
# 25%      35235.250000   35468.500000   2203.000000             NaN
# 50%      70319.500000   70614.000000   3919.000000             NaN
# 75%     105542.750000  105627.750000   4841.000000             NaN
# max     140681.000000  139493.000000   4841.000000             NaN
#
#           CustomerId     ProductId     ChannelId        Amount         Value  \
# count   95662.000000  95662.000000  95662.000000  9.566200e+04  9.566200e+04
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean     3126.883590      7.419069      2.622410  6.717846e+03  9.900584e+03
# std      1650.972455      4.655919      0.558568  1.233068e+05  1.231221e+05
# min         1.000000      1.000000      1.000000 -1.000000e+06  2.000000e+00
# 25%      1875.000000      3.000000      2.000000 -5.000000e+01  2.750000e+02
# 50%      3124.000000      6.000000      3.000000  1.000000e+03  1.000000e+03
# 75%      4229.000000     10.000000      3.000000  2.800000e+03  5.000000e+03
# max      7479.000000     27.000000      5.000000  9.880000e+06  9.880000e+06
#
#          FraudResult
# count   95662.000000
# unique           NaN
# top              NaN
# freq             NaN
# mean        0.002018
# std         0.044872
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000

# %%
sns.pairplot(train, hue='FraudResult')

# %%
sns.heatmap(train.corr(), annot=True)

# %%
# creating input features and target variables
X= train.iloc[:,0:9]
Y= train.iloc[:,9]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-e898d34342ef> in <module>
#       1 # creating input features and target variables
# ----> 2 X= train.iloc[:,0:9]
#       3 Y= train.iloc[:,9]
#
# NameError: name 'train' is not defined

# %%
X.head(2)
# Out:
#    TransactionId  BatchId  AccountId SubscriptionId  CustomerId  ProductId  \
# 0          76871    36123       3957            887        4406         10
# 1          73770    15642       4841           3829        4406          6
#
#    ChannelId  Amount  Value
# 0          3  1000.0   1000
# 1          2   -20.0     20

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X= StandardScaler.fit_transform(X)
X
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-7af4ab753920> in <module>
#       1 from sklearn.preprocessing import StandardScaler
#       2 sc = StandardScaler()
# ----> 3 X= sc.fit_transform(X)
#       4 X
#
# NameError: name 'X' is not defined
